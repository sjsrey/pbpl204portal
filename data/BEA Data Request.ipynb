# %% [markdown]
# # Bureau of Economic Analysis (BEA) API Data Retrieval for  QGIS Plugin
#
# BEA API documentation is available [here](https://apps.bea.gov/api/_pdf/bea_web_service_api_user_guide.pdf)

# %%
import requests
import pandas as pd
import config 

api_key = config.bea_key  #file with API key

# %% [markdown]
# #### The BEA API request will contain the following URL (or a similar URL) with its own required parameters
#
# https://apps.bea.gov/api/data/UserID=Your36CharacterKey&method=GetData&datasetname=Regional&TableName=CAINC1&LineCode=1&Year=2012,2013&GeoFips=COUNTY&ResultFormat=json
#
# *Note that the parameters will change depending on the dataset being requested

# %% [markdown]
# ### From the BEA documentation:
#
# #### LineCode parameter – (required, single value)
# LineCode corresponds to the statistic in a table. Exactly one LineCode must be provided.
#
# #### GeoFips parameter – (required, multiple value)
# GeoFips specifies geography. It can be all states (STATE), all counties (COUNTY), all Metropolitan Statistical Areas (MSA), all Micropolitan Statistical Areas (MIC), all Metropolitan Divisions (DIV), all Combined Statistical Areas (CSA), all metropolitan/nonmetropolitan portions (PORT), or state post office
# abbreviation for all counties in one state (e.g. NY). It can also be a list of ANSI state-county codes or metropolitan area codes. For example, the counties in Connecticut and Delaware– 09001,09003,09005,09007,09009,09011,09013,09015,10001,10003,10005
# State, county, and metropolitan statistical area FIPS codes can be obtained from Census at
# https://www.census.gov/geo/www/ansi/ansi.html.
# A comprehensive list of MSAs and their component counties can be accessed at https://apps.bea.gov/regional/docs/msalist.cfm.
#
# #### Year parameter – (optional, multiple value)
# Year is either a list of comma delimited years, LAST5, LAST10, or ALL. Year will default to LAST5 years if the parameter is not specified.

# %% [markdown]
# ### Data request for the "Personal Income" table (CAINC1 | 1969 ->)  found on the Regional dataset

# %%
#Components of request: 

base = f'https://www.bea.gov/api/data/?&UserID={config.bea_key}'
dset = '&method=GetData&datasetname=Regional'
tbl = '&TableName=CAINC1' 
freq = '&Frequency=Y'
lncode = '&LineCode=1'  #line code found on the second request
yr = '&Year=ALL' #change year accordingly 
geofips = '&GeoFips=STATE'
fmt = '&ResultFormat=json'
url = f'{base}{dset}&TableName={tbl}{freq}{lncode}{yr}{geofips}{fmt}'

# %%
url
# Out:
# 'https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAINC1&Frequency=Y&LineCode=1&Year=ALL&GeoFips=STATE&ResultFormat=json'

# %%
# empty dictionary
results ={}

# %%
linecode = [1,2,3] #linecode from table
for line in linecode:
    lncode = f'&LineCode={line}'
    url = f'{base}{dset}&TableName={tbl}{freq}{lncode}{yr}{geofips}{fmt}'
    results[line] = requests.get(url).json()['BEAAPI']['Results']
    print(url)
# Out:
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAINC1&Frequency=Y&LineCode=1&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAINC1&Frequency=Y&LineCode=2&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAINC1&Frequency=Y&LineCode=3&Year=ALL&GeoFips=STATE&ResultFormat=json

# %%
results.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
results[1]
# Out:
# {'Statistic': 'Personal income',
#  'UnitOfMeasure': 'Thousands of dollars',
#  'PublicTable': 'CAINC1 Personal income (thousands of dollars)',
#  'UTCProductionTime': '2020-05-21T23:21:27.687',
#  'NoteRef': ' ',
#  'Dimensions': [{'Name': 'Code', 'DataType': 'string', 'IsValue': '0

#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '48,422,536'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1984',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '51,504,460'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1985',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '53,629,661'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1986',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '53,695,136'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1987',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '53,932,056'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1988',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '56,881,207'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1989',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '60,326,085'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1990',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '64,880,918'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1991',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '68,408,285'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1992',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '73,263,960'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1993',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '76,872,654'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1994',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '81,905,818'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1995',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '85,953,266'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1996',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '89,776,927'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1997',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '94,400,601'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1998',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '98,943,993'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '1999',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '101,397,141'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2000',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '107,072,494'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2001',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '114,459,006'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2002',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '117,698,461'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2003',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '121,131,961'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2004',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '126,295,608'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2005',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '135,921,323'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2006',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '143,643,335'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2007',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '157,374,298'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2008',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '168,069,987'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2009',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '163,751,636'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2010',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '171,098,211'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2011',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '177,105,109'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2012',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '186,589,357'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2013',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '189,197,094'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2014',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '198,233,896'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2015',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '200,748,457'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2016',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '199,879,233'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2017',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '205,227,413'},
#   {'Code': 'CAINC1-1',
#    'GeoFips': '22000',
#    'GeoName': 'Louisiana',
#    'TimePeriod': '2018',
#    'CL_UNIT': 'Thousands of dollars',
#    'UNIT_MULT': '3',
#    'DataValue': '215,488,654'},
#   ...],
#  'Notes': [{'NoteRef': ' ',
#    'NoteText': 'Metropolitan Areas are defined (geographically delineated) by the Office of Management and Budget bulletin no. 18-04 issued September 14, 2018.'},
#   {'NoteRef': 'Note--',
#    'NoteText': 'All dollar estimates are in thousands of current dollars (not adjusted for inflation). Calculations are performed on unrounded data.'},
#   {'NoteRef': ' ',
#    'NoteText': 'Last updated: November 14, 2019-- new statistics for 2018; revised statistics for 1969-2017.'}]}

# %%
len(results[1])
# Out:
# 8

# %%
for result in results[1]:
    print (len(result))
# Out:
# 9
# 13
# 11
# 17
# 7
# 10
# 4
# 5

# %%
print(results[1])
# Out:
# {'Statistic': 'Personal income', 'UnitOfMeasure': 'Thousands of dollars', 'PublicTable': 'CAINC1 Personal income (thousands of dollars)', 'UTCProductionTime': '2020-05-21T23:21:27.687', 'NoteRef': ' ', 'Dimensions': [{'Name': 'Code', 'DataType': 'string', 'IsValue': '0'}, {'Name': 'GeoFips', 'DataType': 'string', 'IsValue': '0'}, {'Name': 'GeoName', 'DataType': 'string', 'IsValue': '0'}, {'Name': 'TimePeriod', 'DataType': 'string', 'IsValue': '0'}, {'Name': 'DataValue', 'DataType': 'numeric', 'IsValue': '1'}, {'Name': 'CL_UNIT', 'DataType': 'string', 'IsValue': '0'}, {'Name': 'UNIT_MULT', 'DataType': 'numeric', 'IsValue': '0'}], 'Data': [{'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1969', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '791,229,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1970', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '855,525,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1971', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '924,613,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1972', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '1,016,408,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1973', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '1,133,468,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1974', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '1,244,912,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1975', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '1,362,505,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1976', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '1,495,704,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1977', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '1,651,632,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1978', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '1,855,849,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1979', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '2,073,257,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1980', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '2,313,160,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1981', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '2,592,915,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1982', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '2,779,794,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1983', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '2,968,676,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1984', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '3,279,488,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1985', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '3,510,471,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1986', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '3,719,647,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00000', 'GeoName': 'United States', 'TimePeriod': '1987', 'CL_UNIT': 'Thousands of dollars', 'UNIT_MULT': '3', 'DataValue': '3,946,593,000'}, {'Code': 'CAINC1-1', 'GeoFips': '00 ...

# %% [markdown]
# *Note that this request only inlcudes "LineCode 1" which is Personal Income. We will need a loop to gather all three LineCodes

# %% [markdown]
# #### In order to see what Linecodes or variables are avaialble on this table, we need to request them from the BEA
#
# The LineCode request URL will look something like this:
#
# https://apps.bea.gov/api/data/UserID=Your36CharacterKey&method=GetParameterValuesFiltered&datasetname=Regional&TargetParameter=LineCode&TableName=CAINC1&ResultFormat=json

# %%
#Components of LineCode request:

base = f'https://www.bea.gov/api/data/?&UserID={config.bea_key}'
dset = '&method=GetParameterValuesFiltered&datasetname=Regional'
param = '&TargetParameter=LineCode'
tbl = '&TableName=CAINC1' 
fmt = '&ResultFormat=json'
url = f'{base}{dset}&TableName={param}{tbl}{fmt}'

# %%
# Request LineCodes
ln = requests.get(url).json()['BEAAPI']['Results']

# %%
# LineCodes available as will show up as "Key"
ln
# Out:
# {'ParamValue': [{'Key': '1', 'Desc': '[CAINC1] Personal income'},
#   {'Key': '2', 'Desc': '[CAINC1] Population'},
#   {'Key': '3', 'Desc': '[CAINC1] Per capita personal income'}]}

# %% [markdown]
# We see that table CAINC1 has three different variables: personal income, population, and per capita personal income.

# %% [markdown]
# ### Data request for "Total Employment" table (CAEMP25N | 2001 ->)

# %% [markdown]
# Requesting the LineCodes for Total Employment

# %%
#Components of LineCode request:

base = f'https://www.bea.gov/api/data/?&UserID={config.bea_key}'
dset = '&method=GetParameterValuesFiltered&datasetname=Regional'
param = '&TargetParameter=LineCode'
tbl = '&TableName=CAEMP25N' 
fmt = '&ResultFormat=json'
url = f'{base}{dset}&TableName={param}{tbl}{fmt}'

# %%
ln2 = requests.get(url).json()['BEAAPI']['Results']

# %%
ln2
# Out:
# {'ParamValue': [{'Key': '10', 'Desc': '[CAEMP25N] Total employment'},
#   {'Key': '100',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Forestry, fishing, and related activities (NAICS:113-115)'},
#   {'Key': '1000',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Finance and insurance (NAICS:52)'},
#   {'Key': '1100',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Real estate and rental and leasing (NAICS:53)'},
#   {'Key': '1200',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Professional, scientific, and technical services (NAICS:54)'},
#   {'Key': '1300',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Management of companies and enterprises (NAICS:55)'},
#   {'Key': '1400',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Administrative and support and waste management and remediation services (NAICS:56)'},
#   {'Key': '1500',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Educational services (NAICS:61)'},
#   {'Key': '1600',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Health care and social assistance (NAICS:62)'},
#   {'Key': '1700',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Arts, entertainment, and recreation (NAICS:71)'},
#   {'Key': '1800',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Accommodation and food services (NAICS:72)'},
#   {'Key': '1900',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Other services (except government and government enterprises) (NAICS:81)'},
#   {'Key': '20', 'Desc': '[CAEMP25N] Wage and salary employment'},
#   {'Key': '200',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Mining, quarrying, and oil and gas extraction (NAICS:21)'},
#   {'Key': '2000',
#    'Desc': '[CAEMP25N] Employment: Government and government enterprises'},
#   {'Key': '2001',
#    'Desc': '[CAEMP25N] Govt. and govt. enterprises employment: Federal civilian'},
#   {'Key': '2002',
#    'Desc': '[CAEMP25N] Govt. and govt. enterprises employment: Military'},
#   {'Key': '2010',
#    'Desc': '[CAEMP25N] Govt. and govt. enterprises employment: State and local'},
#   {'Key': '2011',
#    'Desc': '[CAEMP25N] Govt. and govt. enterprises employment: State government'},
#   {'Key': '2012',
#    'Desc': '[CAEMP25N] Govt. and govt. enterprises employment: Local government'},
#   {'Key': '300',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Utilities (NAICS:22)'},
#   {'Key': '40', 'Desc': '[CAEMP25N] Proprietors employment'},
#   {'Key': '400',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Construction (NAICS:23)'},
#   {'Key': '50', 'Desc': '[CAEMP25N] Farm proprietors employment'},
#   {'Key': '500',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Manufacturing (NAICS:31-33)'},
#   {'Key': '60', 'Desc': '[CAEMP25N] Nonfarm proprietors employment'},
#   {'Key': '600',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Wholesale trade (NAICS:42)'},
#   {'Key': '70', 'Desc': '[CAEMP25N] Farm employment (NAICS:111-112)'},
#   {'Key': '700',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Retail trade (NAICS:44-45)'},
#   {'Key': '80', 'Desc': '[CAEMP25N] Nonfarm employment'},
#   {'Key': '800',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Transportation and warehousing (NAICS:48-49)'},
#   {'Key': '90', 'Desc': '[CAEMP25N] Private nonfarm employment'},
#   {'Key': '900',
#    'Desc': '[CAEMP25N] Private nonfarm employment: Information (NAICS:51)'}]}

# %% [markdown]
# #### Creating the url for "total employment" (line code '10')
# Note that we are still using the same dataset "Regional".

# %%
#Components of request: 

base = f'https://www.bea.gov/api/data/?&UserID={config.bea_key}'
dset = '&method=GetData&datasetname=Regional'
tbl = '&TableName=CAEMP25N' 
freq = '&Frequency=Y'
lncode = '&LineCode=10'  #line code 
yr = '&Year=ALL' #change year accordingly 
geofips = '&GeoFips=STATE'
fmt = '&ResultFormat=json'
url = f'{base}{dset}&TableName={tbl}{freq}{lncode}{yr}{geofips}{fmt}'

# %%
linecode = [10,100, 20, 200, 300, 40, 400,50, 500, 60, 600, 70, 700, 80, 800, 90, 900] #linecode from table
for line in linecode:
    lncode = f'&LineCode={line}'
    url = f'{base}{dset}&TableName={tbl}{freq}{lncode}{yr}{geofips}{fmt}'
    results[line] = requests.get(url).json()['BEAAPI']['Results']
    print(url)
# Out:
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=10&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=100&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=20&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=200&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=300&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=40&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=400&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=50&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=500&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=60&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=600&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=70&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=700&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=80&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=800&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=90&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25N&Frequency=Y&LineCode=900&Year=ALL&GeoFips=STATE&ResultFormat=json

# %% [markdown]
# ### Data request for "Total Employment" table (CAEMP25S | 1969-2000)

# %%
#Components of LineCode request for CAEMP25S:

base = f'https://www.bea.gov/api/data/?&UserID={config.bea_key}'
dset = '&method=GetParameterValuesFiltered&datasetname=Regional'
param = '&TargetParameter=LineCode'
tbl = '&TableName=CAEMP25S' 
fmt = '&ResultFormat=json'
url = f'{base}{dset}&TableName={param}{tbl}{fmt}'

# %%
ln3 = requests.get(url).json()['BEAAPI']['Results']

# %%
ln3
# Out:
# {'ParamValue': [{'Key': '10', 'Desc': '[CAEMP25S] Total employment'},
#   {'Key': '100',
#    'Desc': '[CAEMP25S] Private nonfarm earnings: Agricultural services, forestry, and fishing (SIC:[07-09])'},
#   {'Key': '20', 'Desc': '[CAEMP25S] Wage and salary employment'},
#   {'Key': '200',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Mining (SIC:B)'},
#   {'Key': '300',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Construction (SIC:C)'},
#   {'Key': '40', 'Desc': '[CAEMP25S] Proprietors employment'},
#   {'Key': '400',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Manufacturing (SIC:D)'},
#   {'Key': '50', 'Desc': '[CAEMP25S] Farm proprietors employment'},
#   {'Key': '500',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Transportation and public utilities (SIC:E)'},
#   {'Key': '60', 'Desc': '[CAEMP25S] Nonfarm proprietors employment'},
#   {'Key': '610',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Wholesale trade (SIC:F)'},
#   {'Key': '620',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Retail trade (SIC:G)'},
#   {'Key': '70', 'Desc': '[CAEMP25S] Farm employment (SIC:[01-02])'},
#   {'Key': '700',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Finance, insurance, and real estate (SIC:H)'},
#   {'Key': '80', 'Desc': '[CAEMP25S] Nonfarm employment'},
#   {'Key': '800',
#    'Desc': '[CAEMP25S] Private nonfarm employment: Services (SIC:I)'},
#   {'Key': '90', 'Desc': '[CAEMP25S] Private nonfarm employment'},
#   {'Key': '900',
#    'Desc': '[CAEMP25S] Employment: Government and government enterprises'},
#   {'Key': '910',
#    'Desc': '[CAEMP25S] Govt. and govt. enterprises employment: Federal civilian'},
#   {'Key': '920',
#    'Desc': '[CAEMP25S] Govt. and govt. enterprises employment: Military'},
#   {'Key': '930',
#    'Desc': '[CAEMP25S] Govt. and govt. enterprises employment: State and local'},
#   {'Key': '931',
#    'Desc': '[CAEMP25S] Govt. and govt. enterprises employment: State government'},
#   {'Key': '932',
#    'Desc': '[CAEMP25S] Govt. and govt. enterprises employment: Local government'}]}

# %% [markdown]
# #### Data request

# %%
#Components of request: 

base = f'https://www.bea.gov/api/data/?&UserID={config.bea_key}'
dset = '&method=GetData&datasetname=Regional'
tbl = '&TableName=CAEMP25S' 
freq = '&Frequency=Y'
lncode = '&LineCode=10'  #line code 
yr = '&Year=ALL' #change year accordingly (1969 - 2000)
geofips = '&GeoFips=STATE'
fmt = '&ResultFormat=json'
url = f'{base}{dset}&TableName={tbl}{freq}{lncode}{yr}{geofips}{fmt}'

# %%
linecode = [10,100, 20, 200, 300, 40, 400,50, 500, 60, 610, 620, 70, 700, 80, 800, 90, 900, 910, 920, 930, 931, 932] #linecode from table
for line in linecode:
    lncode = f'&LineCode={line}'
    url = f'{base}{dset}&TableName={tbl}{freq}{lncode}{yr}{geofips}{fmt}'
    results[line] = requests.get(url).json()['BEAAPI']['Results']
    print(url)
# Out:
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=10&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=100&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=20&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=200&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=300&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=40&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=400&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=50&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=500&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=60&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=610&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=620&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=70&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=700&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=80&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=800&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=90&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=900&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=910&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=920&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=930&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=931&Year=ALL&GeoFips=STATE&ResultFormat=json
# https://www.bea.gov/api/data/?&UserID=391C0530-53C3-475E-A42F-FAD82DB51025&method=GetData&datasetname=Regional&TableName=&TableName=CAEMP25S&Frequency=Y&LineCode=932&Year=ALL&GeoFips=STATE&ResultFormat=json

# %%
results.keys()
# Out:
# dict_keys([1, 2, 3, 10, 100, 20, 200, 300, 40, 400, 50, 500, 60, 600, 70, 700, 80, 800, 90, 900, 610, 620, 910, 920, 930, 931, 932])

# %%
import json

with open('results.json', 'w') as fp:
    json.dump(results, fp)
